# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat-malvi/DBMS/blob/main/Supervised-learning/naiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Naive Bayes Algorithm
#
# 1. **Data Split**
#    - Split the dataset into training and testing sets (60-40% or 80-20%).
#
# 2. **Training**
#    - Create a dictionary of unique words in the training data.
#    - Calculate word probabilities for each class (e.g., spam and not spam) and store them.
#    - Estimate prior probabilities for each class.
#
# 3. **Testing**
#    - For each test instance, calculate class probabilities and classify based on the highest probability.
#    - Compare predictions with actual labels to assess performance.
#
# 4. **Evaluation Metrics**
#    - Calculate **Accuracy**, **Recall**, **Precision**, and **F1 Score** to evaluate the model.
#
# For this algorithm, we use data from [GitHub](https://github.com/atmabodha/selfshiksha/blob/main/Supervised%20Learning%20Basics/SelfShiksha_SLB_MCQ_31_NaiveBayes_EmailClassification/SMSSpamCollection).

# %% [markdown]
# 1. Write a code to implement the Naive Bayes algo on your own.
#
# 2. Explore the Naive Bayes module in sklearn, and compare it with your own code results.
#
# 3. Write a code that takes a list of actual output values (0s and 1s) and another list of predicted values (again 0s and 1s), and computes the following statistics: accuracy, TP, TN, FP, FN, Recall, Precision and F1 score. Compare your results with equivalent modules in sklearn.

# %%
import pandas as pd
df = pd.read_csv('./SMSSpamCollection.txt', sep='\t', header=None, names=['Label', 'SMS'])
df
# Out:
#      Label                                                SMS
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

def tokenization(sent):
    # Use regular expression to remove unwanted characters
    cleaned_sent = re.sub(r'[^a-zA-Z\s]', '', sent)

    # Tokenize the cleaned sentence
    original_words = word_tokenize(cleaned_sent)

    # Define stop words
    stop_words = set(stopwords.words('english'))

    # Filter out stop words
    filtered_tokens = [word.lower() for word in original_words if word.lower() not in stop_words]

    # Print results
    # print("Original Tokens:", original_words)
    # print("Filtered Tokens:", filtered_tokens)

    return filtered_tokens

# string = "Text and Expressions: Use a relational database (like PostgreSQL) or a document store (like MongoDB) to store text and expressions. Store each chapter or section as a separate document/record with clear segmentation for headings, paragraphs, and inline expressions."

# tokenization(string)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#  probability of pos and neg
dct = dict(df['Label'].value_counts())
# dct

prob_posi = dct['ham']/(dct['ham']+dct['spam'])
print(prob_posi)
prob_neg = 1- prob_posi
print(prob_neg)
# Out:
# 0.8659368269921034
# 0.1340631730078966

# %%
dbDict = {}

# %%
# counting Store
def train_data(df,splitor,dbDict):
  # train_rainge= 5560
  for index, row in df.iterrows():
      if index > splitor:
          break

      label = row['Label']
      text = row['SMS']

      if label not in dbDict:
          dbDict[label] = {}

      words = tokenization(text)

      for word in words:
          if word not in dbDict[label]:
              dbDict[label][word] = 0
          dbDict[label][word] += 1


  return dbDict

# %%
#  lang-chain module
#  cromedb

# %%
# Out:
# 0.031267217630853994

# %%
def computation(query_tockens,positive,dbDict,isPositive):
  total_prob = positive
  if isPositive:
    val = 'ham'
  else:
    val = 'spam'

  # total_words = len(dbDict[val].keys())
  # word sum
  total_words = 0
  for i in dbDict[val].values():
    total_words += i


  for word in query_tockens:
    word_count = dbDict[val].get(word)
    if word_count is None:
      word_count = 0

    prob = word_count/total_words
    total_prob *= prob

  return total_prob

# %%
# Naive Bayes Algorithm for SMS Spam Classification
def naive_bayes(df,splitor):
  splitor = len(df) - int(splitor*len(df))

  # Dictionary to hold word probabilities for each class
  dbDict= {}
  dbDict = train_data(df,splitor,dbDict)

  # Calculate prior probabilities for each class
  dct = dict(df['Label'].value_counts())
  prob_positive = dct['ham']/(dct['ham']+dct['spam'])
  prob_negative = dct['spam']/(dct['ham']+dct['spam'])

  # To claculate TP,TN,FP,FP
  tp = 0
  tn = 0
  fp = 0
  fn = 0

  # Iterate through test set, classify messages, and compare predictions
  for i in range(splitor,len(df)):
    query  = df['SMS'][i]
    query_word = tokenization(query)

    # Compute probabilities for each class
    positive_computation = computation(query_word,prob_positive,dbDict,True)
    negative_computation = computation(query_word,prob_negative,dbDict,False)

    # Classify based on computed scores and print result
    if positive_computation > negative_computation:
        print(df['Label'][i], ' ham ', df['SMS'][i])
        if df['Label'][i] == 'ham':
          tp += 1
        else:
          fp += 1
    else:
        print(df['Label'][i], ' spam ',df['SMS'][i])
        if df['Label'][i] == 'spam':
          tn += 1
        else:
          fn += 1

  recall = tp/(tp+fn)
  precison = tp/(tp+fp)
  acuurecy = (tp+tn)/(tp+tn+fp+fn)
  f1= 2*(recall*precison)/(recall+precison)

  print("\n\n")
  print({"TP":tp,"TN":tn,"FP":fp,"FN":fn})
  print(f"recall:{recall}\n precison:{precison} \n Accurecy:{acuurecy} \n F1:{f1}")

# %%
naive_bayes(df,0.2)
# Out:
# ham  ham  Aight should I just plan to come up later tonight?
# ham  spam  Die... I accidentally deleted e msg i suppose 2 put in e sim archive. Haiz... I so sad...
# spam  spam  Welcome to UK-mobile-date this msg is FREE giving you free calling to 08719839835. Future mgs billed at 150p daily. To cancel send "go stop" to 89123
# ham  spam  This is wishing you a great day. Moji told me about your offer and as always i was speechless. You offer so easily to go to great lengths on my behalf and its stunning. My exam is next friday. After that i will keep in touch more. Sorry.
# ham  spam  Thanks again for your reply today. When is ur visa coming in. And r u still buying the gucci and bags. My sister things are not easy, uncle john also has his own bills so i really need to think about how to make my own money. Later sha.
# ham  spam  Sorry I flaked last night, shit's seriously goin down with my roommate, what you up to tonight?
# ham  ham  He said i look pretty wif long hair wat. But i thk he's cutting quite short 4 me leh.
# ham  ham  Ranjith cal drpd Deeraj and deepak 5min hold
# ham  spam  CHEERS FOR CALLIN BABE.SOZI CULDNT TALKBUT I WANNATELL U DETAILS LATER WENWECAN CHAT PROPERLY X
# ham  ham  Hey u still at the gym?
# ham  ham  She said,'' do u mind if I go into the bedroom for a minute ? '' ''OK'', I sed in a sexy mood. She came out 5 minuts latr wid a cake...n My Wife,
# ham  ham  Much better now thanks lol
# ham  spam  Nothing, smsing u n xy lor. Sorry lor da guys neva c u in person but they sort of know u lor. So u wan 2 meet them xy ask me 2 bring u along 4 our next meeting.
# ham  ham  Lemme know when I can swing by and pick up, I'm free basically any time after 1 all this semester
# ham  spam  Wa... U so efficient... Gee... Thanx...
# spam  spam  3. You have received your mobile content. Enjoy
# ham  ham  S but not able to sleep.
# spam  spam  Want explicit SEX in 30 secs? Ring 02073162414 now! Costs 20p/min
# ham  ham  We will meet soon princess! Ttyl!
# ham  ham  I'll pick you up at about 5.15pm to go to taunton if you still want to come.
# ham  ham  Oh :-)only 4 outside players allowed to play know
# ham  ham  I anything lor.
# ham  spam  Erutupalam thandiyachu
# ham  spam  Y cant u try new invention to fly..i'm not joking.,
# ham  spam  No..its ful of song lyrics..
# ham  ham  What do u reckon as need 2 arrange transport if u can't do it, thanks
# ham  spam  True lov n care wil nevr go unrecognized. though somone often makes mistakes when valuing it. but they will definitly undrstnd once when they start missing it.
# ham  spam  Shopping? Eh ger i toking abt syd leh...Haha
# ham  ham  What not under standing.
# ham  ham  have * good weekend.
# ham  spam  Miss call miss call khelate kintu opponenter miss call dhorte lage. Thats d rule. One with great phone receiving quality wins.
# ham  ham  Call me when you get the chance plz &lt;3
# ham  ham  The new deus ex game comin early next yr
# ham  spam  My computer just fried the only essential part we don't keep spares of because my fucking idiot roommates looovvve leaving the thing running on full  &lt;#&gt; /7
# ham  spam  My friend, she's studying at warwick, we've planned to go shopping and to concert tmw, but it may be canceled, havn't seen  for ages, yeah we should get together sometime!
# ham  spam  Probably a couple hours tops
# ham  ham  LOL .. *grins* .. I'm not babe, but thanks for thinking of me!
# ham  ham  Man this bus is so so so slow. I think you're gonna get there before me
# ham  ham  Hope this text meets you smiling. If not then let this text give you a reason to smile. Have a beautiful day.
# ham  spam  In case you wake up wondering where I am, I forgot I have to take care of something for grandma today, should be done before the parade
# ham  ham  Ok
# spam  spam  Latest Nokia Mobile or iPOD MP3 Player +£400 proze GUARANTEED! Reply with: WIN to 83355 now! Norcorp Ltd.£1,50/Mtmsgrcvd18+
# spam  spam  SMS SERVICES. for your inclusive text credits, pls goto www.comuk.net login= 3qxj9 unsubscribe with STOP, no extra charge. help 08702840625.COMUK. 220-CM2 9AE
# ham  ham  Nvm take ur time.
# ham  ham  So wat's da decision?
# ham  ham  Wot is u up 2 then bitch?
# ham  ham  Stupid.its not possible
# ham  spam  She told to hr that he want posting in chennai:)because i'm working here:)
# spam  spam  Mobile Club: Choose any of the top quality items for your mobile. 7cfca1a
# ham  ham  When are you guys leaving?
# ham  spam  He neva grumble but i sad lor... Hee... Buy tmr lor aft lunch. But we still meetin 4 lunch tmr a not. Neva hear fr them lei. Ü got a lot of work ar?
# ham  ham  Not able to do anything.
# ham  spam  Ü takin linear algebra today?
# ham  spam  This weekend is fine (an excuse not to do too much decorating)
# ham  ham  Sorry I missed you babe. I was up late and slept in. I hope you enjoy your driving lesson, boytoy. I miss you too ... *teasing kiss*
# ham  ham  Now project pa. After that only i can come.
# spam  spam  Money i have won wining number 946 wot do i do next
# ham  ham  Sure, whenever you show the fuck up &gt;:(
# ham  spam  That was random saw my old roomate on campus. He graduated
# spam  spam  Congrats! 2 mobile 3G Videophones R yours. call 09061744553 now! videochat wid ur mates, play java games, Dload polyH music, noline rentl. bx420. ip4. 5we. 150pm
# ham  spam  Men always needs a beautiful, intelligent, caring, loving, adjustable, cooperative wife. But the law allows only one wife....
# ham  ham  That sucks. So what do you got planned for your yo valentine? I am your yo valentine aren't I?
# ham  spam  Just got part Nottingham - 3 hrs 63miles. Good thing i love my man so much, but only doing 40mph. Hey ho
# ham  spam  What to think no one saying clearly. Ok leave no need to ask her. I will go if she come or not
# ham  spam  Hi good mornin.. Thanku wish u d same..
# ham  spam  DO U WANT 2 MEET UP 2MORRO
# ham  ham  Actually I decided I was too hungry so I haven't left yet :V
# ham  ham  I've sent ü my part..
# ham  spam  Cos i was out shopping wif darren jus now n i called him 2 ask wat present he wan lor. Then he started guessing who i was wif n he finally guessed darren lor.
# spam  spam  I want some cock! My hubby's away, I need a real man 2 satisfy me. Txt WIFE to 89938 for no strings action. (Txt STOP 2 end, txt rec £1.50ea. OTBox 731 LA1 7WS. )
# ham  spam  Understand. his loss is my gain :) so do you work? School?
# ham  spam  HOW ARE U? I HAVE MISSED U! I HAVENT BEEN UP 2 MUCH A BIT BORED WITH THE HOLIDAY WANT 2 GO BAK 2 COLLEGE! SAD ISNT IT?xx
# ham  ham  Hiya, probably coming home * weekend after next
# ham  spam  Don't forget though that I love you .... And I walk beside you. Watching over you and keeping your heart warm.
# ham  spam  I wish things were different. I wonder when i will be able to show you how much i value you. Pls continue the brisk walks no drugs without askin me please and find things to laugh about. I love you dearly.
# ham  ham  Ok both our days. So what are you making for dinner tonite? Am I invited?
# spam  spam  Gr8 new service - live sex video chat on your mob - see the sexiest dirtiest girls live on ur phone - 4 details text horny to 89070 to cancel send STOP to 89070
# ham  spam  I have no money 4 steve mate! !
# ham  spam  IM LATE TELLMISS IM ON MY WAY
# ham  ham  Never blame a day in ur life. Good days give u happiness. Bad days give u experience. Both are essential in life! All are Gods blessings! good morning.:
# ham  ham  Normally i use to drink more water daily:)
# ham  ham  Dare i ask... Any luck with sorting out the car?
# ham  spam  Party's at my place at usf, no charge (but if you can contribute in any way it is greatly appreciated) and yeah, we got room for one more
# ham  spam  Urgh, coach hot, smells of chip fat! Thanks again, especially for the duvet (not a predictive text word).
# ham  ham  Hiya. How was last night? I've been naughty and bought myself clothes and very little ... Ready for more shopping tho! What kind of time do you wanna meet?
# spam  spam  FreeMsg Hi baby wow just got a new cam moby. Wanna C a hot pic? or Fancy a chat?Im w8in 4uTxt / rply CHAT to 82242 Hlp 08712317606 Msg150p 2rcv
# ham  ham  I've been trying to reach him without success
# ham  ham  when you and derek done with class?
# ham  spam  Never y lei... I v lazy... Got wat? Dat day ü send me da url cant work one...
# ham  ham  Never try alone to take the weight of a tear that comes out of ur heart and falls through ur eyes... Always remember a STUPID FRIEND is here to share... BSLVYL
# ham  spam  Hey mate. Spoke to the mag people. We‘re on.  the is deliver by the end of the month. Deliver on the 24th sept. Talk later.
# ham  ham  Hope you are having a good week. Just checking in
# ham  ham  Haha, my friend tyler literally just asked if you could get him a dubsack
# ham  spam  Hey! do u fancy meetin me at 4 at cha  hav a lil beverage on me. if not txt or ring me and we can meet up l8r. quite tired got in at 3 v.pist ;) love Pete x x x
# ham  spam  Great. Have a safe trip. Dont panic surrender all.
# ham  spam  SYMPTOMS when U are in love: "1.U like listening songs 2.U get stopped where u see the name of your beloved 3.U won't get angry when your
# ham  ham  Sun ah... Thk mayb can if dun have anythin on... Thk have to book e lesson... E pilates is at orchard mrt u noe hor...
# ham  ham  Try to do something dear. You read something for exams
# ham  ham  7 wonders in My WORLD 7th You 6th Ur style 5th Ur smile 4th Ur Personality 3rd Ur Nature 2nd Ur SMS and 1st "Ur Lovely Friendship"... good morning dear
# ham  spam  Gettin rdy to ship comp
# ham  ham  I am in hospital da. . I will return home in evening
# ham  spam  PISS IS TALKING IS SOMEONE THAT REALISE U THAT POINT THIS AT IS IT.(NOW READ IT BACKWARDS)
# ham  ham  Think + da. You wil do.
# ham  ham  I'm awake oh. What's up.
# ham  spam  Good afternoon my boytoy. How goes that walking here and there day ? Did you get that police abstract? Are you still out and about? I wake and miss you babe
# ham  ham  How much u trying to get?
# ham  spam  Come around  &lt;DECIMAL&gt; pm vikky..i'm otside nw, il come by tht time
# ham  ham  Tell me again what your address is
# ham  ham  Honeybee Said: *I'm d Sweetest in d World* God Laughed &amp; Said: *Wait,U Havnt Met d Person Reading This Msg* MORAL: Even GOD Can Crack Jokes! GM+GN+GE+GN:)
# ham  ham  Should i buy him a blackberry bold 2 or torch. Should i buy him new or used. Let me know. Plus are you saying i should buy the  &lt;#&gt; g wifi ipad. And what are you saying about the about the  &lt;#&gt; g?
# ham  ham  But you were together so you should be thinkin about him
# ham  spam  hiya hows it going in sunny africa? hope u r avin a good time. give that big old silver back a big kiss from me.
# ham  ham  At WHAT TIME should i come tomorrow
# spam  spam  Wanna have a laugh? Try CHIT-CHAT on your mobile now! Logon by txting the word: CHAT and send it to No: 8883 CM PO Box 4217 London W1A 6ZF 16+ 118p/msg rcvd
# ham  spam  CHA QUITEAMUZING THATSCOOL BABE,PROBPOP IN & CU SATTHEN HUNNY 4BREKKIE! LOVE JEN XXX. PSXTRA LRG PORTIONS 4 ME PLEASE
# ham  ham  Omg how did u know what I ate?
# spam  spam  URGENT! This is the 2nd attempt to contact U!U have WON £1000CALL 09071512432 b4 300603t&csBCM4235WC1N3XX.callcost150ppmmobilesvary. max£7. 50
# ham  ham  :( but your not here....
# ham  spam  Not directly behind... Abt 4 rows behind ü...
# spam  spam  Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066
# spam  spam  Had your contract mobile 11 Mnths? Latest Motorola, Nokia etc. all FREE! Double Mins & Text on Orange tariffs. TEXT YES for callback, no to remove from records
# spam  spam  Urgent! call 09066350750 from your landline. Your complimentary 4* Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150 ppm 18+
# ham  ham  No plans yet. What are you doing ?
# ham  spam  Hi ....My engagement has been fixd on  &lt;#&gt; th of next month. I know its really shocking bt....hmm njan vilikkam....t ws al of a sudn;-(.
# ham  spam  Not course. Only maths one day one chapter with in one month we can finish.
# ham  spam  Wow didn't think it was that common. I take it all back ur not a freak! Unless u chop it off:-)
# spam  spam  For ur chance to win a £250 wkly shopping spree TXT: SHOP to 80878. T's&C's www.txt-2-shop.com custcare 08715705022, 1x150p/wk
# ham  spam  Noooooooo please. Last thing I need is stress. For once in your life be fair.
# spam  spam  U have a Secret Admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09065171142-stopsms-08718727870150ppm
# spam  spam  Mila, age23, blonde, new in UK. I look sex with UK guys. if u like fun with me. Text MTALK to 69866.18 . 30pp/txt 1st 5free. £1.50 increments. Help08718728876
# ham  spam  I'll see if I can swing by in a bit, got some things to take care of here firsg
# ham  spam  I wanted to wish you a Happy New Year and I wanted to talk to you about some legal advice to do with when Gary and I split but in person. I'll make a trip to Ptbo for that. I hope everything is good with you babe and I love ya :)
# ham  ham  Have you not finished work yet or something?
# ham  ham  Tomorrow i am not going to theatre. . . So i can come wherever u call me. . . Tell me where and when to come tomorrow
# spam  spam  Well done ENGLAND! Get the official poly ringtone or colour flag on yer mobile! text TONE or FLAG to 84199 NOW! Opt-out txt ENG STOP. Box39822 W111WX £1.50
# ham  ham  Right it wasnt you who phoned it was someone with a number like yours!
# ham  ham  It's ok i wun b angry. Msg u aft i come home tonight.
# ham  ham  I had a good time too. Its nice to do something a bit different with my weekends for a change. See ya soon
# ham  ham  Yo sorry was in the shower sup
# ham  ham  Carlos is down but I have to pick it up from him, so I'll swing by usf in a little bit
# ham  spam  Full heat pa:-) i have applyed oil pa.
# ham  ham  I'm stuck in da middle of da row on da right hand side of da lt...
# ham  spam  Have you laid your airtel line to rest?
# ham  spam  Hi did u decide wot 2 get 4 his bday if not ill prob jus get him a voucher frm virgin or sumfing
# spam  spam  FreeMsg: Txt: CALL to No: 86888 & claim your reward of 3 hours talk time to use from your phone now! Subscribe6GBP/mnth inc 3hrs 16 stop?txtStop
# ham  spam  Hey j! r u feeling any better, hopeSo hunny. i amnow feelin ill & ithink i may have tonsolitusaswell! damn iam layin in bedreal bored. lotsof luv me xxxx
# ham  ham  And I don't plan on staying the night but I prolly won't be back til late
# ham  ham  THANX 4 PUTTIN DA FONE DOWN ON ME!!
# ham  ham  I need an 8th but I'm off campus atm, could I pick up in an hour or two?
# ham  spam  Oh... Haha... Den we shld had went today too... Gee, nvm la... Kaiez, i dun mind goin jazz oso... Scared hiphop open cant catch up...
# ham  spam  Been running but only managed 5 minutes and then needed oxygen! Might have to resort to the roller option!
# ham  ham  We live in the next  &lt;#&gt; mins
# ham  ham  Y de asking like this.
# ham  ham  Just glad to be talking to you.
# ham  ham  Wat time ü finish?
# ham  ham  Sorry da. I gone mad so many pending works what to do.
# ham  ham  How much you got for cleaning
# ham  ham  hows my favourite person today? r u workin hard? couldn't sleep again last nite nearly rang u at 4.30
# spam  spam  Sunshine Quiz! Win a super Sony DVD recorder if you canname the capital of Australia? Text MQUIZ to 82277. B
# ham  ham  Ü called dad oredi...
# ham  ham  Good. do you think you could send me some pix? I would love to see your top and bottom...
# ham  spam  Nvm... I'm going to wear my sport shoes anyway... I'm going to be late leh.
# ham  ham  Sorry, I'll call later In meeting.
# ham  spam  THIS IS A LONG FUCKIN SHOWR
# ham  spam  Received, understood n acted upon!
# ham  spam  They finally came to fix the ceiling.
# ham  spam  U need my presnts always bcz U cant mis love. "jeevithathile irulinae neekunna prakasamanu sneham" prakasam ennal prabha 'That mns prabha is'LOVE' Got it. Dont mis me....
# ham  spam  Jus finish blowing my hair. U finish dinner already?
# ham  ham  I'm on the bus. Love you
# ham  ham  Lol ... I knew that .... I saw him in the dollar store
# spam  spam  Please call our customer service representative on 0800 169 6031 between 10am-9pm as you have WON a guaranteed £1000 cash or £5000 prize!
# spam  spam  Todays Voda numbers ending with 7634 are selected to receive a £350 reward. If you have a match please call 08712300220 quoting claim code 7684 standard rates apply.
# ham  ham  Only saturday and sunday holiday so its very difficult:)
# ham  ham  Everybody had fun this evening. Miss you.
# ham  ham  Got hella gas money, want to go on a grand nature adventure with galileo in a little bit?
# ham  ham  I'm in a meeting, call me later at
# ham  spam  Oh wow thats gay. Will firmware update help
# ham  ham  These won't do. Have to move on to morphine
# ham  ham  How come i din c ü... Yup i cut my hair...
# ham  ham  K k pa Had your lunch aha.
# ham  ham  Oh ho. Is this the first time u use these type of words
# ham  spam  Captain vijaykanth is doing comedy in captain tv..he is drunken :)
# ham  ham  Of course. I guess god's just got me on hold right now.
# ham  spam  Do you hide anythiing or keeping distance from me
# ham  ham  Havent.
# spam  spam  You are being ripped off! Get your mobile content from www.clubmoby.com call 08717509990 poly/true/Pix/Ringtones/Games six downloads for only 3
# ham  spam  Sorry i din lock my keypad.
# ham  ham  Did u got that persons story
# ham  ham  Are you planning to come chennai?
# spam  spam  We tried to contact you re your reply to our offer of a Video Phone 750 anytime any network mins Half Price Line Rental Camcorder Reply or call 08000930705
# ham  spam  God created gap btwn ur fingers so dat sum1 vry special will fill those gaps by holding ur hands.. Now plz dont ask y he created so much gap between legs !!!
# ham  ham  We are okay. Going to sleep now. Later
# ham  ham  Please protect yourself from e-threats. SIB never asks for sensitive information like Passwords,ATM/SMS PIN thru email. Never share your password with anybody.
# ham  spam  Finally it has happened..! Aftr decades..! BEER is now cheaper than PETROL! The goverment expects us to "DRINK". . . But don't "DRIVE "
# spam  spam  A £400 XMAS REWARD IS WAITING FOR YOU! Our computer has randomly picked you from our loyal mobile customers to receive a £400 reward. Just call 09066380611
# ham  ham  Where r e meeting tmr?
# ham  spam  Lol yes. But it will add some spice to your day.
# ham  ham  Hope you are having a great day.
# ham  spam  Our Prasanth ettans mother passed away last night. Just pray for her and family.
# ham  ham  K, I'll work something out
# spam  spam  PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S. I. M. points. Call 08718738002 Identifier Code: 48922 Expires 21/11/04
# ham  spam  This message is from a great Doctor in India:-): 1) Do not drink APPY FIZZ. It contains Cancer causing age
# ham  ham  I cant pick the phone right now. Pls send a message
# ham  ham  You call him and tell now infront of them. Call him now.
# ham  ham  Ok no prob...
# ham  spam  Ladies first and genus second k .
# ham  ham  No. Yes please. Been swimming?
# ham  spam  Mum not going robinson already.
# ham  ham  Ok set let u noe e details later...
# ham  spam  Not..tel software name..
# ham  spam  I send the print  outs da.
# ham  spam  IM REALY SOZ IMAT MY MUMS 2NITE WHAT ABOUT 2MORO
# ham  spam  When I was born, GOD said, "Oh No! Another IDIOT". When you were born, GOD said, "OH No! COMPETITION". Who knew, one day these two will become FREINDS FOREVER!
# ham  spam  I didnt get ur full msg..sometext is missing, send it again
# ham  ham  Probably not, I'm almost out of gas and I get some cash tomorrow
# spam  spam  Customer service announcement. We recently tried to make a delivery to you but were unable to do so, please call 07099833605 to re-schedule. Ref:9280114
# ham  ham  I forgot 2 ask ü all smth.. There's a card on da present lei... How? Ü all want 2 write smth or sign on it?
# ham  ham  I'm leaving my house now.
# spam  spam  Hi babe its Chloe, how r u? I was smashed on saturday night, it was great! How was your weekend? U been missing me? SP visionsms.com Text stop to stop 150p/text
# ham  ham  Ü ready then call me...
# ham  spam  Wewa is 130. Iriver 255. All 128 mb.
# ham  spam  It is a good thing I'm now getting the connection to bw
# ham  spam  Sry da..jst nw only i came to home..
# ham  ham  That's cool he'll be here all night, lemme know when you're around
# ham  ham  Are you staying in town ?
# ham  ham  Haha yeah, 2 oz is kind of a shitload
# ham  ham  Ok u can take me shopping when u get paid =D
# ham  ham  My life Means a lot to me, Not because I love my life, But because I love the people in my life, The world calls them friends, I call them my World:-).. Ge:-)..
# ham  ham  Alright we'll bring it to you, see you in like  &lt;#&gt;  mins
# ham  ham  But pls dont play in others life.
# ham  ham  Eatin my lunch...
# ham  spam  Hmmm.but you should give it on one day..
# ham  ham  Didn't try, g and I decided not to head out
# ham  ham  Ok no prob
# ham  spam  Surly ill give it to you:-) while coming to review.
# ham  spam  By march ending, i should be ready. But will call you for sure. The problem is that my capital never complete. How far with you. How's work and the ladies
# ham  ham  Tessy..pls do me a favor. Pls convey my birthday wishes to Nimya..pls dnt forget it. Today is her birthday Shijas
# ham  ham  Pls give her the food preferably pap very slowly with loads of sugar. You can take up to an hour to give it. And then some water. Very very slowly.
# spam  spam  URGENT! Your Mobile No 07808726822 was awarded a £2,000 Bonus Caller Prize on 02/09/03! This is our 2nd attempt to contact YOU! Call 0871-872-9758 BOX95QU
# ham  ham  A guy who gets used but is too dumb to realize it.
# ham  spam  Okey dokey, i‘ll be over in a bit just sorting some stuff out.
# ham  ham  Don no da:)whats you plan?
# ham  ham  Yes fine
# spam  spam  WIN: We have a winner! Mr. T. Foley won an iPod! More exciting prizes soon, so keep an eye on ur mobile or visit www.win-82050.co.uk
# ham  ham  I liked the new mobile
# ham  spam  Anytime...
# ham  spam  Mmmmmmm *snuggles into you* ...*deep contented sigh* ... *whispers* ... I fucking love you so much I can barely stand it ...
# ham  spam  Yar but they say got some error.
# ham  ham  Hey anyway i have to :-)
# ham  spam  Wow so healthy. Old airport rd lor. Cant thk of anything else. But i'll b bathing my dog later.
# ham  ham  Wif my family booking tour package.
# ham  ham  Did you say bold, then torch later. Or one torch and 2bold?
# ham  ham  Haha awesome, I might need to take you up on that, what you doin tonight?
# ham  spam  Ya i knw u vl giv..its ok thanks kano..anyway enjoy wit ur family wit 1st salary..:-);-)
# ham  ham  Huh so slow i tot u reach long ago liao... U 2 more days only i 4 more leh...
# ham  spam  Thats cool princess! I will cover your face in hot sticky cum :)
# ham  spam  Big brother‘s really scraped the barrel with this shower of social misfits
# ham  ham  Oops i thk i dun haf enuff... I go check then tell ü..
# ham  ham  S:)8 min to go for lunch:)
# ham  ham  Hey. What happened? U switch off ur cell d whole day. This isnt good. Now if u do care, give me a call tomorrow.
# ham  ham  K will do, addie &amp; I are doing some art so I'll be here when you get home
# ham  ham  My uncles in Atlanta. Wish you guys a great semester.
# ham  spam  Aiyo... Her lesson so early... I'm still sleepin, haha... Okie, u go home liao den confirm w me lor...
# ham  spam  Forgot to tell ü smth.. Can ü like number the sections so that it's clearer..
# ham  ham  Yup. Anything lor, if u dun wan it's ok...
# ham  ham  I'm home, my love ... If your still awake ... *loving kiss*
# ham  spam  HELLO PEACH! MY CAKE TASTS LUSH!
# spam  spam  FREE GAME. Get Rayman Golf 4 FREE from the O2 Games Arcade. 1st get UR games settings. Reply POST, then save & activ8. Press 0 key for Arcade. Termsapply
# ham  spam  There'll be a minor shindig at my place later tonight, you interested?
# ham  ham  Jason says it's cool if we pick some up from his place in like an hour
# spam  spam  Had your mobile 10 mths? Update to the latest Camera/Video phones for FREE. KEEP UR SAME NUMBER, Get extra free mins/texts. Text YES for a call
# ham  spam  I (Career Tel) have added u as a contact on INDYAROCKS.COM to send FREE SMS. To remove from phonebook - sms NO to  &lt;#&gt;
# ham  ham  I've reached already.
# ham  ham  I dont know ask to my brother. Nothing problem some thing that. Just i told .
# ham  spam  K:)eng rocking in ashes:)
# ham  spam  Wat time r ü going to xin's hostel?
# ham  spam  Good Morning my Dear Shijutta........... Have a great &amp; successful day.
# spam  spam  Buy Space Invaders 4 a chance 2 win orig Arcade Game console. Press 0 for Games Arcade (std WAP charge) See o2.co.uk/games 4 Terms + settings. No purchase
# ham  spam  Oh k:)after that placement there ah?
# ham  spam  Not for possession, especially not first offense
# ham  spam  Nt only for driving even for many reasons she is called BBD..thts it chikku, then hw abt dvg cold..heard tht vinobanagar violence hw is the condition..and hw ru ? Any problem?
# ham  spam  I bought the test yesterday. Its something that lets you know the exact day u ovulate.when will get 2u in about 2 to 3wks. But pls pls dont fret. I know u r worried. Pls relax. Also is there anything in ur past history u need to tell me?
# ham  ham  We have pizza if u want
# ham  spam  I keep seeing weird shit and bein all "woah" then realising it's actually reasonable and I'm all "oh"
# ham  ham  Many more happy returns of the day. I wish you happy birthday.
# ham  ham  Ya very nice. . .be ready on thursday
# ham  ham  I am in hospital da. . I will return home in evening
# ham  ham  Thinking of u ;) x
# spam  spam  Camera - You are awarded a SiPix Digital Camera! call 09061221066 fromm landline. Delivery within 28 days.
# ham  spam  Orh i tot u say she now still dun believe.
# ham  ham  When you just put in the + sign, choose my number and the pin will show. Right?
# ham  spam  The beauty of life is in next second.. which hides thousands of secrets. I wish every second will be wonderful in ur life...!! gud n8
# ham  spam  Thanx u darlin!im cool thanx. A few bday drinks 2 nite. 2morrow off! Take care c u soon.xxx
# ham  ham  If you're still up, maybe leave the credit card so I can get gas when I get back like he told me to
# spam  spam  Your weekly Cool-Mob tones are ready to download !This weeks new Tones include: 1) Crazy Frog-AXEL F>>> 2) Akon-Lonely>>> 3) Black Eyed-Dont P >>>More info in n
# ham  ham  Well boy am I glad G wasted all night at applebees for nothing
# spam  spam  Cashbin.co.uk (Get lots of cash this weekend!) www.cashbin.co.uk Dear Welcome to the weekend We have got our biggest and best EVER cash give away!! These..
# ham  ham  Ok lor... Or u wan me go look 4 u?
# ham  spam  U wan 2 haf lunch i'm in da canteen now.
# ham  spam  Don't make life too stressfull.. Always find time to Laugh.. It may not add years to your Life! But surely adds more life to ur years!! Gud ni8..swt dreams..
# ham  ham  hey, looks like I was wrong and one of the kappa guys numbers is still on my phone, if you want I can text him and see if he's around
# spam  spam  URGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09061790121 from land line. Claim 3030. Valid 12hrs only 150ppm
# spam  spam  Thanks 4 your continued support Your question this week will enter u in2 our draw 4 £100 cash. Name the NEW US President? txt ans to 80082
# ham  ham  I'm home. Doc gave me pain meds says everything is fine.
# ham  spam  It's é only $140 ard...É rest all ard $180 at least...Which is é price 4 é 2 bedrm ($900)
# ham  ham  Me too! Have a lovely night xxx
# ham  spam  Prepare to be pleasured :)
# ham  spam  Hi.:)technical support.providing assistance to us customer through call and email:)
# ham  ham  if you text on your way to cup stop that should work. And that should be BUS
# ham  ham  Whens your radio show?
# spam  spam  Your unique user ID is 1172. For removal send STOP to 87239 customer services 08708034412
# ham  ham  I'm not sure if its still available though
# ham  spam  watever reLation u built up in dis world only thing which remains atlast iz lonlines with lotz n lot memories! feeling..
# ham  spam  CHEERS LOU! YEAH WAS A GOODNITE SHAME U NEVA CAME! C YA GAILxx
# ham  spam  Hi..i got the money da:)
# ham  ham  Hi, Mobile no.  &lt;#&gt;  has added you in their contact list on www.fullonsms.com It s a great place to send free sms to people For more visit fullonsms.com
# ham  ham  Ok then u tell me wat time u coming later lor.
# ham  spam  U repeat e instructions again. Wat's e road name of ur house?
# ham  ham  So many people seems to be special at first sight, But only very few will remain special to you till your last sight.. Maintain them till life ends.. Sh!jas
# ham  spam  Quite lor. But dun tell him wait he get complacent...
# ham  ham  Sorry completely forgot * will pop em round this week if your still here?
# ham  ham  U R THE MOST BEAUTIFUL GIRL IVE EVER SEEN. U R MY BABY COME AND C ME IN THE COMMON ROOM
# ham  spam  O we cant see if we can join denis and mina? Or does denis want alone time
# ham  ham  Sen told that he is going to join his uncle finance in cbe
# ham  spam  Yup... Hey then one day on fri we can ask miwa and jiayin take leave go karaoke
# ham  spam  Call me, i am senthil from hsbc.
# ham  spam  Especially since i talk about boston all up in my personal statement, lol! I woulda changed that if i had realized it said nyc! It says boston now.
# ham  ham  Indeed and by the way it was either or - not both !
# spam  spam  Urgent -call 09066649731from Landline. Your complimentary 4* Ibiza Holiday or £10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150ppm 18+
# ham  ham  Holy living christ what is taking you so long
# ham  ham  Ü thk of wat to eat tonight.
# ham  spam  Thanx. Yup we coming back on sun. Finish dinner going back 2 hotel now. Time flies, we're tog 4 exactly a mth today. Hope we'll haf many more mths to come...
# ham  spam  We're on the opposite side from where we dropped you off
# ham  spam  Yup. Izzit still raining heavily cos i'm in e mrt i can't c outside.
# ham  ham  Send me your resume:-)
# ham  ham  Gd luck 4 ur exams :-)
# ham  ham  Or u ask they all if next sat can a not. If all of them can make it then i'm ok lor.
# ham  ham  Sorry that was my uncle. I.ll keep in touch
# ham  spam  Saw Guys and Dolls last night with Patrick Swayze it was great
# spam  spam  URGENT This is our 2nd attempt to contact U. Your £900 prize from YESTERDAY is still awaiting collection. To claim CALL NOW 09061702893
# spam  spam  Santa calling! Would your little ones like a call from Santa Xmas Eve? Call 09077818151 to book you time. Calls1.50ppm last 3mins 30s T&C www.santacalling.com
# ham  spam  Just come home. I don't want u to be miserable
# ham  ham  I dont know why she.s not getting your messages
# ham  spam  its cool but tyler had to take off so we're gonna buy for him and drop it off at his place later tonight. Our total order is a quarter, you got enough?
# ham  spam  The guy at the car shop who was flirting with me got my phone number from the paperwork and called and texted me. I'm nervous because of course now he may have my address. Should i call his boss and tell him, knowing this may get him fired?
# ham  ham  Reverse is cheating. That is not mathematics.
# ham  ham  How do you plan to manage that
# ham  spam  Er, hello, things didn‘t quite go to plan – is limping slowly home followed by aa and with exhaust hanging off
# ham  ham  Sorry for the delay. Yes masters
# ham  ham  Call me when u finish then i come n pick u.
# spam  spam  PRIVATE! Your 2004 Account Statement for 078498****7 shows 786 unredeemed Bonus Points. To claim call 08719180219 Identifier Code: 45239 Expires 06.05.05
# ham  spam  What's up my own oga. Left my phone at home and just saw ur messages. Hope you are good. Have a great weekend.
# ham  spam  Don't worry though, I understand how important it is that I be put in my place with a poorly thought out punishment in the face of the worst thing that has ever happened to me. Brb gonna go kill myself
# ham  spam  Honey, can you pls find out how much they sell Predicte in Nigeria. And how many times can it be used. Its very important to have a reply before monday
# ham  ham  E admin building there? I might b slightly earlier... I'll call u when i'm reaching...
# ham  ham  fyi I'm at usf now, swing by the room whenever
# ham  ham  i can call in  &lt;#&gt;  min if thats ok
# ham  ham  Ummmmmaah Many many happy returns of d day my dear sweet heart.. HAPPY BIRTHDAY dear
# ham  ham  Ü no home work to do meh...
# ham  spam  Anything is valuable in only 2 situations: First- Before getting it... Second- After loosing it...
# ham  ham  Me too. Mark is taking forever to pick up my prescription and the pain is coming back.
# ham  ham  How's ur paper?
# ham  spam  Got smaller capacity one? Quite ex...
# spam  spam  Check Out Choose Your Babe Videos @ sms.shsex.netUN fgkslpoPW fgkslpo
# ham  ham  Im good! I have been thinking about you...
# spam  spam  u r a winner U ave been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810710p/min (18 )
# ham  ham  :-) :-)
# ham  ham  Not thought bout it... || Drink in tap & spile at seven. || Is that pub on gas st off broad st by canal. || Ok?
# ham  ham  I am going to sleep. I am tired of travel.
# ham  ham  Haha, just what I was thinkin
# ham  ham  Yup but it's not giving me problems now so mayb i'll jus leave it...
# ham  ham  Lol no. Just trying to make your day a little more interesting
# ham  spam  How long before you get reply, just defer admission til next semester
# ham  spam  The word "Checkmate" in chess comes from the Persian phrase "Shah Maat" which means; "the king is dead.." Goodmorning.. Have a good day..:)
# ham  ham  Po de :-):):-):-):-). No need job aha.
# ham  spam  Rats. Hey did u ever vote for the next themes?
# spam  spam  New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today! From ONLY £1. www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18 TXTAUCTION.
# ham  spam  I hope your pee burns tonite.
# ham  ham  OH RITE. WELL IM WITH MY BEST MATE PETE, WHO I WENT OUT WITH 4 A WEEK+ NOW WERE 2GEVA AGAIN. ITS BEEN LONGER THAN A WEEK.
# ham  ham  Yay can't wait to party together!
# ham  spam  ....photoshop makes my computer shut down.
# ham  ham  All boys made fun of me today. Ok i have no problem. I just sent one message just for fun
# ham  spam  That's one of the issues but california is okay. No snow so its manageable
# spam  spam  PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S. I. M. points. Call 08715203652 Identifier Code: 42810 Expires 29/10/0
# ham  spam  Hmmm.... Mayb can try e shoppin area one, but forgot e name of hotel...
# ham  ham  Awesome, that gonna be soon or later tonight?
# ham  ham  I need details about that online job.
# spam  spam  YOU HAVE WON! As a valued Vodafone customer our computer has picked YOU to win a £150 prize. To collect is easy. Just call 09061743386
# ham  spam  Missing you too.pray inshah allah
# ham  spam  Pls help me tell Ashley that i cant find her number oh
# ham  ham  I am in escape theatre now. . Going to watch KAVALAN in a few minutes
# ham  spam  S.this will increase the chance of winning.
# ham  ham  either way works for me. I am  &lt;#&gt;  years old. Hope that doesnt bother you.
# ham  ham  Maybe you should find something else to do instead???
# ham  spam  Gain the rights of a wife.dont demand it.i am trying as husband too.Lets see
# ham  ham  I liked your new house
# ham  ham  I'm fine. Hope you are also
# ham  spam  Also north carolina and texas atm, you would just go to the gre site and pay for the test results to be sent.
# ham  ham  Same to u...
# ham  ham  yes baby! I need to stretch open your pussy!
# ham  spam  Thanks  and ! Or bomb and date as my phone wanted to say!
# ham  ham  Ok...
# ham  spam  Hey, a guy I know is breathing down my neck to get him some bud, anyway you'd be able to get a half track to usf tonight?
# ham  spam  Response is one of d powerful weapon 2 occupy a place in others 'HEART'... So, always give response 2 who cares 4 U"... Gud night..swt dreams..take care
# ham  spam  Nokia phone is lovly..
# spam  spam  **FREE MESSAGE**Thanks for using the Auction Subscription Service. 18 . 150p/MSGRCVD 2 Skip an Auction txt OUT. 2 Unsubscribe txt STOP CustomerCare 08718726270
# spam  spam  Bored housewives! Chat n date now! 0871750.77.11! BT-national rate 10p/min only from landlines!
# ham  spam  Sorry da..today i wont come to play..i have driving clas..
# ham  spam  I'm really sorry I lit your hair on fire
# ham  spam  Oh! Shit, I thought that was your trip! Loooooool ... That just makes SO much more sense now ... *grins* and the sofa reference was ... The "sleep on a couch" link you sent me ... Wasn't that how you went on your trip ? Oh ... And didn't your babe go with you for that celebration with your rents?
# ham  spam  Okey dokey swashbuckling stuff what oh.
# ham  ham  Watching cartoon, listening music &amp; at eve had to go temple &amp; church.. What about u?
# ham  spam  1. Tension face 2. Smiling face 3. Waste face 4. Innocent face 5.Terror face 6.Cruel face 7.Romantic face 8.Lovable face 9.decent face  &lt;#&gt; .joker face.
# ham  spam  Dip's cell dead. So i m coming with him. U better respond else we shall come back.
# ham  ham  Well. You know what i mean. Texting
# ham  spam  Hi dis is yijue i would be happy to work wif ü all for gek1510...
# ham  ham  Lol! Oops sorry! Have fun.
# ham  spam  Wat happened to the cruise thing
# ham  spam  I know dat feelin had it with Pete! Wuld get with em , nuther place nuther time mayb?
# spam  spam  lyricalladie(21/F) is inviting you to be her friend. Reply YES-910 or NO-910. See her: www.SMS.ac/u/hmmross STOP? Send STOP FRND to 62468
# ham  spam  The world's most happiest frnds never have the same characters... Dey just have the best understanding of their differences...
# spam  spam  No 1 POLYPHONIC tone 4 ur mob every week! Just txt PT2 to 87575. 1st Tone FREE ! so get txtin now and tell ur friends. 150p/tone. 16 reply HL 4info
# ham  spam  Yeah just open chat and click friend lists. Then make the list. Easy as pie
# ham  spam  alright tyler's got a minor crisis and has to be home sooner than he thought so be here asap
# ham  spam  When/where do I pick you up
# ham  ham  As usual u can call me ard 10 smth.
# ham  ham  New Theory: Argument wins d SITUATION, but loses the PERSON. So dont argue with ur friends just.. . . . kick them &amp; say, I'm always correct.!
# ham  spam  For many things its an antibiotic and it can be used for chest abdomen and gynae infections even bone infections.
# ham  ham  Poor girl can't go one day lmao
# ham  ham  Or just do that 6times
# spam  spam  Todays Vodafone numbers ending with 4882 are selected to a receive a £350 award. If your number matches call 09064019014 to receive your £350 award.
# ham  spam  You have to pls make a note of all she.s exposed to. Also find out from her school if anyone else was vomiting. Is there a dog or cat in the house? Let me know later.
# ham  ham  Japanese Proverb: If one Can do it, U too Can do it, If none Can do it,U must do it Indian version: If one Can do it, LET HIM DO it.. If none Can do it,LEAVE it!! And finally Kerala version: If one can do it, Stop him doing it.. If none can do it, Make a strike against it ...
# ham  spam  Sounds like there could be a lot of time spent in that chastity device boy ... *grins* ... Or take your beatings like a good dog. Going to lounge in a nice long bath now ?
# ham  spam  Its worse if if uses half way then stops. Its better for him to complete it.
# ham  spam  Miserable. They don't tell u that the side effects of birth control are massive gut wrenching cramps for the first 2 months. I didn't sleep at all last night.
# ham  spam  Send me the new number
# ham  ham  Convey my regards to him
# spam  spam  Want the latest Video handset? 750 anytime any network mins? Half price line rental? Reply or call 08000930705 for delivery tomorrow
# ham  ham  2 and half years i missed your friendship:-)
# ham  ham  I cant pick the phone right now. Pls send a message
# ham  spam  Oh for fuck's sake she's in like tallahassee
# ham  ham  Haha, that was the first person I was gonna ask
# spam  spam  ou are guaranteed the latest Nokia Phone, a 40GB iPod MP3 player or a £500 prize! Txt word: COLLECT to No: 83355! IBHltd LdnW15H 150p/Mtmsgrcvd18
# ham  spam  Taka lor. Wat time u wan 2 come n look 4 us?
# spam  spam  * FREE* POLYPHONIC RINGTONE Text SUPER to 87131 to get your FREE POLY TONE of the week now! 16 SN PoBox202 NR31 7ZS subscription 450pw
# ham  ham  I;m reaching in another 2 stops.
# ham  spam  no, i *didn't* mean to post it. I wrote it, and like so many other times i've ritten stuff to you, i let it sit there. it WAS what i was feeling at the time. I was angry. Before i left, i hit send, then stop. It wasn't there. I checked on my phone when i got to my car. It wasn't there. You said you didn't sleep, you were bored. So why wouldn't THAT be the time to clean, fold laundry, etc.? At least make the bed?
# spam  spam  Warner Village 83118 C Colin Farrell in SWAT this wkend @Warner Village & get 1 free med. Popcorn!Just show msg+ticket@kiosk.Valid 4-7/12. C t&c @kiosk. Reply SONY 4 mre film offers
# ham  ham  Will you come online today night
# ham  ham  Then anything special?
# ham  spam  I'm in solihull, | do you want anything?
# ham  ham  Will do. Have a good day
# ham  spam  WE REGRET TO INFORM U THAT THE NHS HAS MADE A MISTAKE.U WERE NEVER ACTUALLY BORN.PLEASE REPORT 2 YOR LOCAL HOSPITAL 2B TERMINATED.WE R SORRY 4 THE INCONVENIENCE
# ham  spam  Love that holiday Monday feeling even if I have to go to the dentists in an hour
# ham  ham  I am on the way to tirupur.
# spam  spam  Goal! Arsenal 4 (Henry, 7 v Liverpool 2 Henry scores with a simple shot from 6 yards from a pass by Bergkamp to give Arsenal a 2 goal margin after 78 mins.
# ham  spam  You've already got a flaky parent. It'snot supposed to be the child's job to support the parent...not until they're The Ride age anyway. I'm supposed to be there to support you. And now i've hurt you. unintentional. But hurt nonetheless.
# ham  spam  We took hooch for a walk toaday and i fell over! Splat! Grazed my knees and everything! Should have stayed at home! See you tomorrow!
# ham  ham  Just dropped em off, omw back now
# spam  spam  This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize. 2 claim is easy, call 08712101358 NOW! Only 10p per min. BT-national-rate
# ham  ham  Sitting in mu waiting for everyone to get out of my suite so I can take a shower
# ham  ham  Re your call; You didn't see my facebook huh?
# ham  spam  G says you never answer your texts, confirm/deny
# ham  spam  Its so common hearin How r u? Wat r u doing? How was ur day? So let me ask u something different. Did u smile today? If not, do it now.... Gud evng.
# ham  ham  Hi Dear Call me its urgnt. I don't know whats your problem. You don't want to work or if you have any other problem at least tell me. Wating for your reply.
# ham  spam  Oh yah... We never cancel leh... Haha
# ham  ham  We can go 4 e normal pilates after our intro...
# ham  ham  Ok... Let u noe when i leave my house.
# ham  spam  Oh yes, why is it like torture watching england?
# ham  ham  Wanna do some art?! :D
# ham  spam  Just hopeing that wasn‘t too pissed up to remember and has gone off to his sisters or something!
# spam  spam  Got what it takes 2 take part in the WRC Rally in Oz? U can with Lucozade Energy! Text RALLY LE to 61200 (25p), see packs or lucozade.co.uk/wrc & itcould be u!
# spam  spam  Hi, the SEXYCHAT girls are waiting for you to text them. Text now for a great night chatting. send STOP to stop this service
# ham  spam  Good morning, my boytoy! How's those yummy lips ? Where's my sexy buns now ? What do you do ? Do you think of me ? Do you crave me ? Do you need me ?
# ham  spam  Match started.india  &lt;#&gt;  for 2
# ham  spam  Once free call me sir.
# ham  ham  Hey do you want anything to buy:)
# ham  ham  Hey babe, how's it going ? Did you ever figure out where your going for New Years ?
# ham  spam  K..k.:)congratulation ..
# ham  ham  G wants to know where the fuck you are
# ham  ham  No it was cancelled yeah baby! Well that sounds important so i understand my darlin give me a ring later on this fone love Kate x
# ham  spam  Tomarrow i want to got to court. At  &lt;DECIMAL&gt; . So you come to bus stand at 9.
# ham  ham  Ü go home liao? Ask dad to pick me up at 6...
# ham  spam  Omg you can make a wedding chapel in frontierville? Why do they get all the good stuff?
# ham  spam  I'm eatin now lor, but goin back to work soon... E mountain deer show huh... I watch b4 liao, very nice...
# ham  spam  Check mail.i have mailed varma and kept copy to you regarding membership.take care.insha allah.
# ham  ham  Wrong phone! This phone! I answer this one but assume the other is people i don't well
# ham  spam  Anyway I don't think I can secure anything up here, lemme know if you want me to drive down south and chill
# ham  ham  I'm already back home so no probably not
# spam  spam  Great News! Call FREEFONE 08006344447 to claim your guaranteed £1000 CASH or £2000 gift. Speak to a live operator NOW!
# spam  spam  Hi this is Amy, we will be sending you a free phone number in a couple of days, which will give you an access to all the adult parties...
# ham  ham  I am in bus on the way to calicut
# ham  spam  Hi its me you are probably having too much fun to get this message but i thought id txt u cos im bored! and james has been farting at me all night
# ham  spam  hi baby im sat on the bloody bus at the mo and i wont be home until about 7:30 wanna do somethin later? call me later ortxt back jess xx
# spam  spam  Welcome to Select, an O2 service with added benefits. You can now call our specially trained advisors FREE from your mobile by dialling 402.
# ham  spam  I lost 4 pounds since my doc visit last week woot woot! Now I'm gonna celebrate by stuffing my face!
# ham  ham  U coming back 4 dinner rite? Dad ask me so i re confirm wif u...
# ham  ham  Doing my masters. When will you buy a bb cos i have for sale and how's bf
# ham  spam  Ahhhh...just woken up!had a bad dream about u tho,so i dont like u right now :) i didnt know anything about comedy night but i guess im up for it.
# ham  spam  I'm vivek:)i got call from your number.
# ham  ham  Why didn't u call on your lunch?
# ham  ham  What i mean was i left too early to check, cos i'm working a 9-6.
# ham  spam  I want  &lt;#&gt;  rs da:)do you have it?
# ham  ham  A bit of Ur smile is my hppnss, a drop of Ur tear is my sorrow, a part of Ur heart is my life, a heart like mine wil care for U, forevr as my GOODFRIEND
# ham  ham  Yup ok...
# ham  ham  I want to see your pretty pussy...
# spam  spam  Dear Voucher holder Have your next meal on us. Use the following link on your pc 2 enjoy a 2 4 1 dining experiencehttp://www.vouch4me.com/etlp/dining.asp
# ham  spam  A few people are at the game, I'm at the mall with iouri and kaila
# spam  spam  URGENT! We are trying to contact U. Todays draw shows that you have won a £2000 prize GUARANTEED. Call 09058094507 from land line. Claim 3030. Valid 12hrs only
# spam  spam  You can donate £2.50 to UNICEF's Asian Tsunami disaster support fund by texting DONATE to 864233. £2.50 will be added to your next bill
# ham  ham  Future is not what we planned for tomorrow.....! it is the result of what we do today...! Do the best in present... enjoy the future.
# ham  spam  I will cme i want to go to hos 2morow. After that i wil cme. This what i got from her dear what to do. She didnt say any time
# ham  ham  We are supposed to meet to discuss abt our trip... Thought xuhui told you? In the afternoon. Thought we can go for lesson after that
# ham  ham  Hey come online! Use msn... We are all there
# ham  ham  I'm fine. Hope you are good. Do take care.
# ham  spam  Oops I was in the shower when u called. Hey a parking garage collapsed at university hospital. See I'm not crazy. Stuff like that DOES happen.
# ham  ham  Aiyo u so poor thing... Then u dun wan 2 eat? U bathe already?
# ham  ham  Yar... I tot u knew dis would happen long ago already.
# ...
# ham  ham  NOT MUCH NO FIGHTS. IT WAS A GOOD NITE!!
# ham  ham  Ok.ok ok..then..whats ur todays plan
# ham  ham  Nt joking seriously i told
# ham  spam  Watching ajith film ah?
# ham  spam  Ooooooh I forgot to tell u I can get on yoville on my phone
# ham  spam  All done, all handed in. Don't know if mega shop in asda counts as celebration but thats what i'm doing!
# ham  ham  I dont know exactly could you ask chechi.
# ham  ham  Dunno lei shd b driving lor cos i go sch 1 hr oni.
# ham  spam  As in i want custom officer discount oh.
# ham  spam  That's necessarily respectful
# ham  ham  Hi. Hope you had a good day. Have a better night.
# ham  spam  And he's apparently bffs with carly quick now
# ham  spam  HARD BUT TRUE: How much you show &amp;  express your love to someone....that much it will hurt when they leave you or you get seperated...!鈥┾??〨ud evening...
# ham  spam  Babes I think I got ur brolly I left it in English wil bring it in 2mrw 4 u luv Franxx
# ham  spam  Hi babe its me thanks for coming even though it didnt go that well!i just wanted my bed! Hope to see you soon love and kisses xxx
# ham  ham  So gd got free ice cream... I oso wan...
# ham  spam  Pls give her prometazine syrup. 5mls then  &lt;#&gt; mins later feed.
# ham  ham  So how many days since then?
# ham  ham  Dear are you angry i was busy dear
# ham  ham  Yup he msg me: is tat yijue? Then i tot it's my group mate cos we meeting today mah... I'm askin if ü leaving earlier or wat mah cos mayb ü haf to walk v far...
# ham  ham  ... Are you in the pub?
# ham  ham  There is a first time for everything :)
# ham  spam  Daddy, shu shu is looking 4 u... U wan me 2 tell him u're not in singapore or wat?
# ham  ham  I ask if u meeting da ge tmr nite...
# ham  spam  Gr8. So how do you handle the victoria island traffic. Plus when's the album due
# ham  spam  Nite nite pocay wocay luv u more than n e thing 4eva I promise ring u 2morrowxxxx
# ham  ham  East coast
# ham  spam  You should get more chicken broth if you want ramen unless there's some I don't know about
# ham  ham  My slave! I want you to take 2 or 3 pictures of yourself today in bright light on your cell phone! Bright light!
# ham  ham  Nope. I just forgot. Will show next week
# ham  ham  So how are you really. What are you up to. How's the masters. And so on.
# ham  spam  I'm at bruce &amp; fowler now but I'm in my mom's car so I can't park (long story)
# ham  ham  I dont know oh. Hopefully this month.
# ham  ham  Hi elaine, is today's meeting confirmed?
# ham  spam  Ok k..sry i knw 2 siva..tats y i askd..
# ham  ham  Sorry, I'll call later
# ham  ham  U horrible gal... U knew dat i was going out wif him yest n u still come n ask me...
# ham  ham  Otherwise had part time job na-tuition..
# ham  spam  Oh yeah! And my diet just flew out the window
# spam  spam  Santa Calling! Would your little ones like a call from Santa Xmas eve? Call 09058094583 to book your time.
# ham  ham  You didnt complete your gist oh.
# ham  spam  Er yeah, i will b there at 15:26, sorry! Just tell me which pub/cafe to sit in and come wen u can
# ham  ham  If you can make it any time tonight or whenever you can it's cool, just text me whenever you're around
# ham  spam  If I was I wasn't paying attention
# ham  ham  Thanx a lot 4 ur help!
# ham  ham  You're gonna have to be way more specific than that
# ham  ham  Jesus armand really is trying to tell everybody he can find
# ham  spam  I'm wif him now buying tix lar...
# ham  ham  Mode men or have you left.
# ham  spam  Am slow in using biola's fne
# ham  spam  What are youdoing later? Sar xxx
# ham  ham  Hey i've booked the 2 lessons on sun liao...
# ham  ham  Thank you. do you generally date the brothas?
# ham  spam  By the way, make sure u get train to worc foregate street not shrub hill. Have fun night x
# ham  spam  I thought i'd get him a watch, just cos thats the kind of thing u get4an18th. And he loves so much!
# spam  spam  You have won a guaranteed 32000 award or maybe even £1000 cash to claim ur award call free on 0800 ..... (18+). Its a legitimat efreefone number wat do u think???
# ham  spam  Good morning. At the repair shop--the ONLY reason i'm up at this hour.
# ham  ham  And that's fine, I got enough bud to last most of the night at least
# ham  spam  I am back. Good journey! Let me know if you need any of the receipts. Shall i tell you like the pendent?
# ham  ham  So that takes away some money worries
# ham  ham  aight we can pick some up, you open before tonight?
# spam  spam  Latest News! Police station toilet stolen, cops have nothing to go on!
# ham  ham  Sac needs to carry on:)
# ham  spam  Just sing HU. I think its also important to find someone female that know the place well preferably a citizen that is also smart to help you navigate through. Even things like choosing a phone plan require guidance. When in doubt ask especially girls.
# ham  ham  What???? Hello wats talks email address?
# ham  spam  Except theres a chick with huge boobs.
# ham  ham  Im just wondering what your doing right now?
# ham  spam  Wishing you a beautiful day. Each moment revealing even more things to keep you smiling. Do enjoy it.
# spam  spam  For the most sparkling shopping breaks from 45 per person; call 0121 2025050 or visit www.shortbreaks.org.uk
# ham  ham  Arun can u transfr me d amt
# ham  ham  Sorry, I'll call later
# ham  spam  If you hear a loud scream in about &lt;#&gt; minutes its cause my Gyno will be shoving things up me that don't belong :/
# spam  spam  December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update Co FREE on 08002986906
# ham  ham  Ok i thk i got it. Then u wan me 2 come now or wat?
# spam  spam  Txt: CALL to No: 86888 & claim your reward of 3 hours talk time to use from your phone now! Subscribe6GBP/mnth inc 3hrs 16 stop?txtStop www.gamb.tv
# ham  ham  U GOIN OUT 2NITE?
# ham  spam  I will treasure every moment we spend together...
# ham  spam  Shall I bring us a bottle of wine to keep us amused? Only joking! I‘ll bring one anyway
# spam  spam  http//tms. widelive.com/index. wml?id=820554ad0a1705572711&first=true¡C C Ringtone¡
# spam  spam  Get your garden ready for summer with a FREE selection of summer bulbs and seeds worth £33:50 only with The Scotsman this Saturday. To stop go2 notxt.co.uk
# spam  spam  URGENT! Last weekend's draw shows that you have won £1000 cash or a Spanish holiday! CALL NOW 09050000332 to claim. T&C: RSTM, SW7 3SS. 150ppm
# ham  ham  Ok lor.
# ham  spam  I thought slide is enough.
# ham  ham  Yup
# ham  ham  Well obviously not because all the people in my cool college life went home ;_;
# ham  ham  Ok lor ü reaching then message me.
# ham  spam  Where's mummy's boy ? Is he being good or bad ? Is he being positive or negative ? Why is mummy being made to wait? Hmmmm?
# ham  spam  Dhoni have luck to win some big title.so we will win:)
# ham  spam  Yes princess! I want to please you every night. Your wish is my command...
# ham  ham  What Today-sunday..sunday is holiday..so no work..
# ham  ham  No probably  &lt;#&gt; %.
# ham  spam  Really do hope the work doesnt get stressful. Have a gr8 day.
# ham  spam  Have you seen who's back at Holby?!
# ham  ham  Shall call now dear having food
# spam  spam  URGENT We are trying to contact you Last weekends draw shows u have won a £1000 prize GUARANTEED Call 09064017295 Claim code K52 Valid 12hrs 150p pm
# ham  spam  So li hai... Me bored now da lecturer repeating last weeks stuff waste time...
# ham  spam  , ,  and  picking them up from various points | going 2 yeovil | and they will do the motor project 4 3 hours | and then u take them home. || 12 2 5.30 max. || Very easy
# ham  spam  Also fuck you and your family for going to rhode island or wherever the fuck and leaving me all alone the week I have a new bong &gt;:(
# ham  spam  Ofcourse I also upload some songs
# spam  spam  2p per min to call Germany 08448350055 from your BT line. Just 2p per min. Check PlanetTalkInstant.com for info & T's & C's. Text stop to opt out
# ham  ham  K. I will sent it again
# ham  spam  Oh thanks a lot..i already bought 2 eggs ..
# ham  ham  K. I will sent it again
# ham  ham  U studying in sch or going home? Anyway i'll b going 2 sch later.
# spam  spam  Marvel Mobile Play the official Ultimate Spider-man game (£4.50) on ur mobile right now. Text SPIDER to 83338 for the game & we ll send u a FREE 8Ball wallpaper
# ham  spam  I think if he rule tamilnadu..then its very tough for our people.
# ham  spam  Cool, we shall go and see, have to go to tip anyway. Are you at home, got something to drop in later? So lets go to town tonight! Maybe mum can take us in.
# ham  ham  Good afternoon, my love ... How goes your day ? How did you sleep ? I hope your well, my boytoy ... I think of you ...
# ham  ham  Yes... I trust u to buy new stuff ASAP so I can try it out
# spam  spam  SMS SERVICES. for your inclusive text credits, pls goto www.comuk.net login= 3qxj9 unsubscribe with STOP, no extra charge. help 08702840625.COMUK. 220-CM2 9AE
# ham  ham  Why did I wake up on my own &gt;:(
# ham  spam  Now get step 2 outta the way. Congrats again.
# ham  ham  Love has one law; Make happy the person you love. In the same way friendship has one law; Never make ur friend feel alone until you are alive.... Gud night
# spam  spam  PRIVATE! Your 2003 Account Statement for 07808247860 shows 800 un-redeemed S. I. M. points. Call 08719899229 Identifier Code: 40411 Expires 06/11/04
# ham  spam  Apo all other are mokka players only
# ham  spam  Perhaps * is much easy give your account identification, so i will tomorrow at UNI
# ham  ham  Wait . I will msg after  &lt;#&gt;  min.
# ham  ham  What i told before i tell. Stupid hear after i wont tell anything to you. You dad called to my brother and spoken. Not with me.
# ham  spam  God's love has no limit. God's grace has no measure. God's power has no boundaries. May u have God's endless blessings always in ur life...!! Gud ni8
# ham  ham  I want to be inside you every night...
# ham  ham  Machan you go to gym tomorrow,  i wil come late goodnight.
# ham  ham  Lol they were mad at first but then they woke up and gave in.
# ham  ham  I went to project centre
# ham  spam  It‘s reassuring, in this crazy world.
# ham  ham  Just making dinner, you ?
# ham  ham  Yes. Please leave at  &lt;#&gt; . So that at  &lt;#&gt;  we can leave
# ham  spam  Oh... Okie lor...We go on sat...
# ham  spam  You are a great role model. You are giving so much and i really wish each day for a miracle but God as a reason for everything and i must say i wish i knew why but i dont. I've looked up to you since i was young and i still do. Have a great day.
# ham  spam  Ya, i'm referin to mei's ex wat... No ah, waitin 4 u to treat, somebody shld b rich liao...So gd, den u dun have to work frm tmr onwards...
# ham  ham  Miles and smiles r made frm same letters but do u know d difference..? smile on ur face keeps me happy even though I am miles away from u.. :-)keep smiling.. Good nyt
# ham  ham  By the way, i've put a skip right outside the front of the house so you can see which house it is. Just pull up before it.
# ham  spam  Can you pls send me that company name. In saibaba colany
# ham  ham  No. I dont want to hear anything
# ham  spam  You are a big chic. Common. Declare
# ham  ham  Thats cool. I want to please you...
# ham  ham  Going to join tomorrow.
# spam  spam  You are awarded a SiPix Digital Camera! call 09061221061 from landline. Delivery within 28days. T Cs Box177. M221BP. 2yr warranty. 150ppm. 16 . p p£3.99
# ham  ham  I want to tell you how bad I feel that basically the only times I text you lately are when I need drugs
# spam  spam  PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S.I.M. points. Call 08718738001 Identifier Code: 49557 Expires 26/11/04
# ham  spam  Total disappointment, when I texted you was the craziest shit got :(
# ham  spam  Its just the effect of irritation. Just ignore it
# ham  ham  What about this one then.
# ham  spam  I think that tantrum's finished so yeah I'll be by at some point
# ham  spam  Compliments to you. Was away from the system. How your side.
# ham  spam  happened here while you were adventuring
# ham  spam  Hey chief, can you give me a bell when you get this. Need to talk to you about this royal visit on the 1st june.
# ham  ham  Ok which your another number
# ham  spam  I know you are thinkin malaria. But relax, children cant handle malaria. She would have been worse and its gastroenteritis. If she takes enough to replace her loss her temp will reduce. And if you give her malaria meds now she will just vomit. Its a self limiting illness she has which means in a few days it will completely stop
# ham  ham  Aiyah ok wat as long as got improve can already wat...
# spam  spam  Want explicit SEX in 30 secs? Ring 02073162414 now! Costs 20p/min Gsex POBOX 2667 WC1N 3XX
# ham  ham  I can't believe how attached I am to seeing you every day. I know you will do the best you can to get to me babe. I will go to teach my class at your midnight
# ham  ham  Just sleeping..and surfing
# spam  spam  ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE MINS. INDIA CUST SERVs SED YES. L8ER GOT MEGA BILL. 3 DONT GIV A SHIT. BAILIFF DUE IN DAYS. I O £250 3 WANT £800
# ham  ham  Yeah it's jus rite...
# ham  ham  Armand says get your ass over to epsilon
# ham  ham  U still havent got urself a jacket ah?
# ham  spam  I'm taking derek &amp; taylor to walmart, if I'm not back by the time you're done just leave the mouse on my desk and I'll text you when priscilla's ready
# ham  ham  Hi its in durban are you still on this number
# ham  spam  Ic. There are a lotta childporn cars then.
# spam  spam  Had your contract mobile 11 Mnths? Latest Motorola, Nokia etc. all FREE! Double Mins & Text on Orange tariffs. TEXT YES for callback, no to remove from records.
# ham  ham  No, I was trying it all weekend ;V
# ham  spam  You know, wot people wear. T shirts, jumpers, hat, belt, is all we know. We r at Cribbs
# ham  ham  Cool, what time you think you can get here?
# ham  spam  Wen did you get so spiritual and deep. That's great
# ham  ham  Have a safe trip to Nigeria. Wish you happiness and very soon company to share moments with
# ham  ham  Hahaha..use your brain dear
# ham  spam  Well keep in mind I've only got enough gas for one more round trip barring a sudden influx of cash
# ham  spam  Yeh. Indians was nice. Tho it did kane me off a bit he he. We shud go out 4 a drink sometime soon. Mite hav 2 go 2 da works 4 a laugh soon. Love Pete x x
# ham  spam  Yes i have. So that's why u texted. Pshew...missing you so much
# ham  spam  No. I meant the calculation is the same. That  &lt;#&gt; units at  &lt;#&gt; . This school is really expensive. Have you started practicing your accent. Because its important. And have you decided if you are doing 4years of dental school or if you'll just do the nmde exam.
# ham  ham  Sorry, I'll call later
# ham  ham  if you aren't here in the next  &lt;#&gt;  hours imma flip my shit
# ham  ham  Anything lor. Juz both of us lor.
# ham  spam  Get me out of this dump heap. My mom decided to come to lowes. BORING.
# ham  spam  Ok lor... Sony ericsson salesman... I ask shuhui then she say quite gd 2 use so i considering...
# ham  ham  Ard 6 like dat lor.
# ham  ham  Why don't you wait 'til at least wednesday to see if you get your .
# ham  ham  Huh y lei...
# spam  spam  REMINDER FROM O2: To get 2.50 pounds free call credit and details of great offers pls reply 2 this text with your valid name, house no and postcode
# spam  spam  This is the 2nd time we have tried 2 contact u. U have won the £750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate.
# ham  ham  Will ü b going to esplanade fr home?
# ham  spam  Pity, * was in mood for that. So...any other suggestions?
# ham  spam  The guy did some bitching but I acted like i'd be interested in buying something else next week and he gave it to us for free
# ham  ham  Rofl. Its true to its name
#
#
#
# {'TP': 538, 'TN': 145, 'FP': 0, 'FN': 431}
# recall:0.5552115583075335
#  precison:1.0
#  Accurecy:0.6131059245960503
#  F1:0.7140013271400133

# %% [markdown]
# # Naive bayes using sklearn algo

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# Load and preprocess data
def load_data(df):
    x = df['SMS']
    y = df['Label'].map({'ham': 0, 'spam': 1})
    return x, y

# Train and evaluate Naive Bayes classifier
def naive_bayes(df, test_size=0.2):
    x, y = load_data(df)

    # Split the data into train and test sets
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=42)

    # Convert text to feature veoctors
    vectorizer = CountVectorizer()

    x_train_vectorized = vectorizer.fit_transform(x_train)
    x_test_vectorized = vectorizer.transform(x_test)

    # Initialize and train the Naive Bayes classifier
    nb_classifier = MultinomialNB()
    nb_classifier.fit(x_train_vectorized, y_train)

    # Make predictions on the test set
    y_pred = nb_classifier.predict(x_test_vectorized)
    print(classification_report(y_test, y_pred, target_names=['ham', 'spam']))
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("\n")

    # Show some predictions
    for text, true_label, predicted_label in zip(x_test[:5], y_test[:5], y_pred[:5]):
        label_str = 'ham' if predicted_label == 0 else 'spam'
        print(f"{'ham' if true_label == 0 else 'spam'} {label_str} {text}")

naive_bayes(df,0.4)
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.99      1.00      0.99      1938
#         spam       0.97      0.94      0.95       291
#
#     accuracy                           0.99      2229
#    macro avg       0.98      0.97      0.97      2229
# weighted avg       0.99      0.99      0.99      2229
#
# Accuracy: 0.9883355764917003
#
#
# ham ham Squeeeeeze!! This is christmas hug.. If u lik my frndshp den hug me back.. If u get 3 u r cute:) 6 u r luvd:* 9 u r so lucky;) None? People hate u:
# ham ham And also I've sorta blown him off a couple times recently so id rather not text him out of the blue looking for weed
# ham ham Mmm thats better now i got a roast down me! id b better if i had a few drinks down me 2! Good indian?
# ham ham Mm have some kanji dont eat anything heavy ok
# ham ham So there's a ring that comes with the guys costumes. It's there so they can gift their future yowifes. Hint hint

# %% [markdown]
# - Write a code that takes a list of actual output values (0s and 1s) and another list of predicted values (again 0s and 1s), and computes the following statistics: accuracy, TP, TN, FP, FN, Recall, Precision and F1 score. Compare your results with equivalent modules in sklearn.
